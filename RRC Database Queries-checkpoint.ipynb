# %% [markdown]
# # Connecting to MySQL database

# %%
# !pip install ipython-sql pymysql SQLAlchemy==1.4.49

# %%
# %reload_ext sql

# %%
# %sql mysql+pymysql://root:Password@localhost:3306/rupert_roof_conversions
# Out:
# 'Connected: root@rupert_roof_conversions'

# %% [markdown]
# ### Testing to show tables

# %%
# 
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %sql SHOW TABLES;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 8 rows affected.
# [('customers',),
#  ('invoice',),
#  ('job_material',),
#  ('job_staff',),
#  ('job_type',),
#  ('jobs',),
#  ('materials',),
#  ('staff',)]

# %%
# %%sql
# Select *
# from rupert_roof_conversions.job_type;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 0 rows affected.
# []

# %% [markdown]
# # Inserting data into tables
#
# - The data used in the table is all hypothetical

# %% [markdown]
# ## 1. Job_type table

# %%
# %%sql
# insert into
# 	rupert_roof_conversions.job_type (
#     jobtype, Daily_rate)
# values
#     ( 'Full conversion', 100.00),
#     ( 'semiconversion', 90.00),
#     ( 'Floor boarding', 75.00)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 3 rows affected.
# []

# %%
# %%sql
# select *
# from rupert_roof_conversions.job_type;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 3 rows affected.
# [(1, 'Full conversion', Decimal('100.00')),
#  (2, 'semiconversion', Decimal('90.00')),
#  (3, 'Floor boarding', Decimal('75.00'))]

# %% [markdown]
# ## 2. Customers table

# %%
# %%sql
# INSERT INTO Customers (Customer_ID, Customer_Name, Street, Area, City, Postcode)
# VALUES
# (001, 'Jay Davidson', '345 High Street', 'Brockley', 'London', 'SE16 U77'),
# (002, 'Charun Jutley', '45 Church Street', 'Nunhead', 'London', 'SE15 2BQ'),
# (003, 'Colin Clark', '67 Robins Avenue', 'Homerton', 'London', 'E9 REE'),
# (004, 'Naseema Khan', '1 Oleander Street', 'Islington', 'London', 'N1 QEE'),
# (005, 'Abdul Hasnath', '90 Togo Road', 'Walthamstow', 'London', 'E17 TYY'),
# (006, 'Winston Kodogo', '32 Lavender Road', 'Leyton', 'London', 'E10 TR5'),
# (007, 'James Strong', '23 Goring Street', 'Homerton', 'London', 'E9 YT5');
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 7 rows affected.
# []

# %%
# %%sql
# select *
# from rupert_roof_conversions.customers
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 5 rows affected.
# [(1, 'Jay Davidson', '345 High Street', 'Brockley', 'London', 'SE16 U77'),
#  (2, 'Charun Jutley', '45 Church Street', 'Nunhead', 'London', 'SE15 2BQ'),
#  (3, 'Colin Clark', '67 Robins Avenue', 'Homerton', 'London', 'E9 REE'),
#  (4, 'Naseema Khan', '1 Oleander Street', 'Islington', 'London', 'N1 QEE'),
#  (5, 'Abdul Hasnath', '90 Togo Road', 'Walthamstow', 'London', 'E17 TYY')]

# %% [markdown]
# ## 3. Staff table

# %%
# %%sql
# INSERT INTO Staff (Staff_id, Staff_name, Contact)
# VALUES
# ('S100', 'Ronald Smith', '07700123456'),
# ('S801', 'Muhammad Ya', '07700234567'),
# ('S20', 'Curtis Stand', '07700345678'),
# ('S11', 'Manny Sinclair', '07700456789'),
# ('S150', 'Sarah Johnson', '07700567890'),
# ('S202', 'David Chen', '07700678901');
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 6 rows affected.
# []

# %%
# %%sql
# Select *
# from staff
# limit 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 3 rows affected.
# [('S100', 'Ronald Smith', '07700123456'),
#  ('S11', 'Manny Sinclair', '07700456789'),
#  ('S150', 'Sarah Johnson', '07700567890')]

# %% [markdown]
# ## 4. Jobs Table

# %%
# %%sql
# INSERT INTO Jobs (Job_id, Customer_id, Jobtype_id, Days, Date_Started, Date_Completed)
# VALUES
# (28434, 1, 1, 8, '2024-01-15', '2024-01-23'),  -- Jay Davidson - Full Conversion
# (29000, 2, 2, 2, '2024-01-20', '2024-01-22'),  -- Charun Jutley - Semi Conversion
# (28501, 3, 3, 2, '2024-01-25', '2024-01-27'),  -- Colin Clark - Floor Boarding
# (26982, 4, 1, 6, '2024-02-01', '2024-02-07'),  -- Naseema Khan - Full Conversion
# (23232, 5, 2, 2, '2024-02-10', '2024-02-12'),  -- Abdul Hasnath - Semi Conversion
# (27611, 6, 1, 7, '2024-02-15', '2024-02-22'),  -- Winston Kodogo - Full Conversion
# (29100, 7, 3, 3, '2024-03-01', '2024-03-04'),  -- James Strong - Floor Boarding
# (29200, 1, 2, 3, '2024-03-10', NULL);          -- Jay Davidson - Semi Conversion (ongoing)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 8 rows affected.
# []

# %%
# %%sql
# select *
# from Jobs
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 5 rows affected.
# [(23232, 5, 2, Decimal('2'), datetime.date(2024, 2, 10), datetime.date(2024, 2, 12)),
#  (26982, 4, 1, Decimal('6'), datetime.date(2024, 2, 1), datetime.date(2024, 2, 7)),
#  (27611, 6, 1, Decimal('7'), datetime.date(2024, 2, 15), datetime.date(2024, 2, 22)),
#  (28434, 1, 1, Decimal('8'), datetime.date(2024, 1, 15), datetime.date(2024, 1, 23)),
#  (28501, 3, 3, Decimal('2'), datetime.date(2024, 1, 25), datetime.date(2024, 1, 27))]

# %% [markdown]
# ## 5. Materials table

# %%
# %%sql
# INSERT INTO Materials (material_id, Material_name, Measure, Unit_price)
# VALUES
# ('M001','Clay Roof Tiles', 'm²', 45.52),
# ('M002','Concrete Roof Tiles', 'm²', 28.75),
# ('M003', 'Natural Slate', 'm²', 85),
# ('M004','Synthetic Slate', 'm²', 52.30),
# ('M005', 'Ridge Tiles - Clay', 'piece', 12.50),
# ('M006', 'Ridge Tiles - Concrete', 'piece', 8.75);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 6 rows affected.
# []

# %%
# %%sql
# select *
# from Materials
# limit 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 3 rows affected.
# [('M001', 'Clay Roof Tiles', 'm²', Decimal('45.52')),
#  ('M002', 'Concrete Roof Tiles', 'm²', Decimal('28.75')),
#  ('M003', 'Natural Slate', 'm²', Decimal('85.00'))]

# %% [markdown]
# ## 6. Job staff table

# %%
# %%sql
# INSERT INTO job_staff (Job_ID, Staff_ID) VALUES
# -- Job 28434 (Jay Davidson - Full Conversion)
# (28434, 'S100'),
# (28434, 'S801'),
# (28434, 'S20'),
#
# -- Job 29000 (Charun Jutley - Semi Conversion)
# (29000, 'S11'),
#
# -- Job 28501 (Colin Clark - Floor Boarding)
# (28501, 'S801'),
# (28501, 'S100'),
# (26982, 'S100'),
# (26982, 'S150'),
# (26982, 'S202');
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 9 rows affected.
# []

# %%
# %%sql
# select *
# from job_staff
# limit 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 3 rows affected.
# [(28434, 'S100'), (28434, 'S801'), (28434, 'S20')]

# %% [markdown]
# ## 7. Job material table

# %%
# %%sql
# INSERT INTO Job_Material (Job_ID, Material_ID, Quantity_Used) VALUES
# -- Job 28434 (Full Conversion - Jay Davidson)
# (28434, 'M001', 80.00),   -- 80 standard floor boards
# (28434, 'M002', 3.00),    -- 3 power points
# (28434, 'M003', 20.00),   -- 20 meters electrical wiring
# (28434, 'M004', 1.00);    -- 1 standard stairs pack
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 4 rows affected.
# []

# %%
# %%sql
# select *
# from Job_Material
# limit 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rupert_roof_conversions
# 3 rows affected.
# [(28434, 'M001', Decimal('80.00')),
#  (28434, 'M002', Decimal('3.00')),
#  (28434, 'M003', Decimal('20.00'))]
